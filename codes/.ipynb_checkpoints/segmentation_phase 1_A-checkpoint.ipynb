# %%
import re
from pathlib import Path
import pandas as pd

data_folder = Path("C:/Users/Jing Li/Desktop/cv2db/project/Inputs")
data_to_open = data_folder / "Resume_A.txt"

# %%
with open(data_to_open) as f: 
	data = f.read()
    
# Seperate each person
pattern = r"Qualifications and Experience"
temp = list(filter(None, re.split(pattern, data)))
del temp[0]

# seperate QE

pattern_QE = r"\n\d+\. "
# QE = [re.split(pattern_QE, i) for i in temp]
QEs = [re.split(pattern_QE, i)[0] for i in temp] # QEs in the form of a list
data = [re.split(pattern_QE, i)[1] for i in temp] # information without QE, a list

# %%
#Checking
# print(len(QE), QE)
# print(len(data), data[0])

# %%
# Split: name and title

name_title = [i.split("\n", 1)[0] for i in data]
ppls_noname = [i.split("\n", 1)[1] for i in data]

name_title = [i.replace(" Summary", "") for i in name_title]

pattern_name = r"\s[–-]\s"
test = [re.split(pattern_name, i) for i in name_title]
name = [re.split(pattern_name, i)[0] for i in name_title]
title = [re.split(pattern_name, i)[1] for i in name_title]

# remove degree from name
name = [re.split(",", i)[0] for i in name]

# %%
#Checking

# print(len(name))
# print(len(title))
# print(name)
# print(title)

# %%
# Split: career summary, education

smmry = [re.split(r"\nEducation\n|Education, Training", ppl)[0] for ppl in ppls_noname]
ppls_nosmy = [re.split(r"\nEducation\n|Education, Training", ppl)[1] for ppl in ppls_noname]

edu_pattern = r"(Selected Project|Relevant Project|Work|Professional)\sExperience"

education = [re.split(edu_pattern, ppl, maxsplit = 1)[0] for ppl in ppls_nosmy]
ppls_noedu = [re.split(edu_pattern, ppl, maxsplit = 1)[2] for ppl in ppls_nosmy]

# %%
# Split: Work Experience
# 16 people has additional materials after work experience

pattern_work = r"\n(Selected |Recent )?Publications.*|(\nSuccessful Grant |\sSelected )?Awards.*|.+ Presentations\n|\nConferences"

# Recent Publications and Presentations
# Publications
# Selected Publications and Technical Reports
# Selected Publications
# Awards and Professional Achievements|and then: Selected Publications
# Recent Technical Reports, and Presentations
# Publications, Technical Reports, and Presentations
# Selected Publications and Presentations
# Publications and Awards
# Publications and Presentations
# Awards
# Awards and Honors
# Successful Grant Awards
# Conferences
# Poster Presentations

ppls = [re.split(pattern_work, i, maxsplit = 1) for i in ppls_noedu]
print(ppls[1][1])
print([len(k) for k in ppls])
# for j in ppls:
#     print(len(j))
wrk = [i[0] for i in ppls]
ppls_others = [i[-1] if len(i) != 1 else None for i in ppls]
# Out:
# None
# [4, 4, 4, 4, 4, 1, 1, 4, 4, 4, 1, 1, 4, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 1, 4, 4, 4, 4, 4, 4, 4, 4, 1, 1, 1, 1, 4, 4, 4, 4, 4, 4, 4, 1, 4, 1, 4, 4, 1, 1, 1, 4]

# %%
7/3 start HERE!!
#Split Work Experience

# further seperate work experience
pattern_exp = r"\n[^\n]+\d{4}\s?[–-]"
wrk_exp_list = [re.split(pattern_exp, i) for i in wrk_exp] # a list of lists of work description
wrk_exp_list1 = [re.findall(pattern_exp, i) for i in wrk_exp] # a list of lists of work_title/time

#Check
# print ([len(i) for i in wrk_exp_list])
# print ([len(i) for i in wrk_exp_list1])

for i in range(len(wrk_exp_list)):
    # wrk_exp_list[i] is a list containing work experiences of i-th consultant
    for j in range(len(wrk_exp_list1[i])):
        wrk_exp_list[i][j+1] = wrk_exp_list1[i][j]+ wrk_exp_list[i][j+1]
        
#Check
# print(wrk_exp_list)
# print ([len(i) for i in wrk_exp_list])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-140-e4d54a772ed5> in <module>
#       3 # further seperate work experience
#       4 pattern_exp = r"\n[^\n]+\d{4}\s?[–-]"
# ----> 5 wrk_exp_list = [re.split(pattern_exp, i) for i in wrk_exp] # a list of lists of work description
#       6 wrk_exp_list1 = [re.findall(pattern_exp, i) for i in wrk_exp] # a list of lists of work_title/time
#       7
#
# NameError: name 'wrk_exp' is not defined

# %%
# Build a simple dataframe to store the chunked information

df2 = pd.DataFrame({"Source": "B",
                    "Name":name,
                    "Title": title,
                    "Qualification and Experience": QEs,
                    "Career Summary": smmry,
                    "ETC": education,
                    "Work Experience": wrk,
                    "Hornors/Awards/Publications": ppls_others,
                    'ppls_noname': ppls_noname}) # for extract keywords, but repetive information (no name, title, QE)

# %%
df2
# Out:
#    Source                   Name  \
# 0       B      Emily L. Abbruzzi
# 1       B      Patricia Andersen
# 2       B             Nina Freed
# 3       B         Noemi Lucciola
# 4       B      Sandra L. Paredes
# 5       B     Elizabeth A. Quinn
# 6       B    Stacey Hall Reddick
# 7       B        Mariana Serrani
# 8       B  Teresa Anne Strickler
# 9       B           West Addison
# 10      B           Carly Mensah
# 11      B  Gregory Randal Miller
# 12      B              Ming Chan
# 13      B       Jenny Namur Karp
# 14      B           Mary Neyhard
# 15      B          Stefani Olsen
# 16      B             Claire Pak
# 17      B             Nigel Shaw
# 18      B          Adam Thompson
# 19      B              Echo Wang
# 20      B           Yinong Chong
# 21      B     Eunice Mafundikwas
# 22      B         Alison Amoroso
# 23      B      Marneena L. Evans
# 24      B        Frank Van Balen
# 25      B           Randy Durbin
# 26      B            Imani Ma’at
# 27      B         Malikah Waajid
# 28      B       Claude Fullerton
# 29      B    Shannon Fair Reefer
# 30      B             Tina Adler
# 31      B   Tina Bogart Marshall
#
#                                                 Title  \
# 0                                   Project Assistant
# 1        Consultant - Meeting Technical Writer/Editor
# 2                                     Data Technician
# 3                                    Website Designer
# 4                              Translator/Interpreter
# 5                                     Project Manager
# 6             Senior Travel and Logistics Coordinator
# 7                            Translator / Interpreter
# 8                   Data Administrator / Statistician
# 9                   Data Administrator / Statistician
# 10                                    Project Manager
# 11                                Training Specialist
# 12                  Information Management Specialist
# 13                                Training Specialist
# 14                                 Travel Coordinator
# 15                                    Project Manager
# 16                                      Writer/Editor
# 17                                     Data Architect
# 18                                Training Specialist
# 19                                    Project Manager
# 20                  Data Administrator / Statistician
# 21                             Senior Writer / Editor
# 22                            Research Analyst/Writer
# 23                         Quality Program Specialist
# 24                                  Corporate Monitor
# 25                   Rural Project Manager / Director
# 26                     Rural Research Analyst/Advisor
# 27  Social Science Analyst (Maternal and Child Hea...
# 28                                   Website Designer
# 29                      Senior Researcher / Clinician
# 30                            Technical Writer/Editor
# 31                      Associate Technical Personnel
#
#                          Qualification and Experience  \
# 0   \nResearch assistant with 4 years of experienc...
# 1   \nEditor and writer with 20 years of experienc...
# 2   \nResearch analyst with 7 years of experience ...
# 3   \nWeb designer with 15 years of experience dev...
# 4   \nHealth communications specialist with 10 yea...
# 5   \nSenior Study Director with 25 years of exper...
# 6   \nRecruitment manager with 14 years of experie...
# 7   \nSenior project director with 18 years of exp...
# 8   \nOver 20 years of experience in sampling, sur...
# 9   \nOver 10 years of statistical programming for...
# 10  \nOver 10 years of experience in project manag...
# 11  \nOver 30 years of experience developing digit...
# 12  \nOver 20 years of software development experi...
# 13  \nOver 15 years of technical assistance includ...
# 14  \nOver 20 years of travel and logistics experi...
# 15  \nOver 17 years of experience working across B...
# 16  \nOver two years of experience supporting HHS ...
# 17  \nOver 30 years of Data Architecture and infor...
# 18  \nOver nine years of training, coaching, and c...
# 19  \nMore than eight years of experience managing...
# 20  \nOver 20 years of as a Health Scientist for t...
# 21  \nOver 12 years of health communications inclu...
# 22  \nOver 25 years of technical assistance to sta...
# 23  \nResearch associate with 15 years of experien...
# 24  \nOver 20 years of corporate and project finan...
# 25  \nPracticing Physician and Medical Epidemiolog...
# 26  \nOver 25 years of public health leadership po...
# 27  \nSkillful in developing comprehensive reports...
# 28  \nOver 18 years of experience as a .NET Develo...
# 29  \nSenior Study Director and Registered Nurse\n...
# 30  \nSenior Science Writer and Editor\nM.S. from ...
# 31  \nPhD in Social Welfare\nLicensed Social Worke...
#
#                                        Career Summary  \
# 0   Emily Abbruzzi is a research assistant with 4 ...
# 1   Patricia Andersen is an editor, writer, and fa...
# 2   Nina Freed is a research analyst with 7 years ...
# 3   Noemi Lucciola is a senior web designer with 1...
# 4   Sandra Paredes is a health communications spec...
# 5   Elizabeth Quinn is a Westat Senior Study Direc...
# 6   Stacey Reddick is a recruitment manager with 1...
# 7   Mariana Serrani is a senior project director w...
# 8   Teresa Strickler is a statistician with 21 yea...
# 9   Career Summary\nMr. Addison is an owner, Direc...
# 10  Career Summary\nAn accomplished professional w...
# 11  Career Summary\nGregory Randal Miller has 30 y...
# 12  Career Summary\n20+ years of software developm...
# 13  Career Summary\nAs the President and Co-Founde...
# 14  Career Summary\nOver 20 years of experience as...
# 15  Career Summary\nMs. Olsen is a certified Proje...
# 16  Claire Pak is a writer and editor with several...
# 17  Career Summary\nSystems architecture, analysis...
# 18  Adam Thompson is a seasoned training specialis...
# 19  Career Summary\nMs. Echo Wang is an experience...
# 20  Career Summary\nAn experienced Data Administra...
# 21  Career Summary\nA senior-level writer/editor w...
# 22  Career Summary\nAn experienced executive lead ...
# 23  Marneena Evans is a research associate with mo...
# 24  Career Summary\nMr. Frank Van Balen is a finan...
# 25  Career Summary\nDr. Durbin is currently the Vi...
# 26  Career Summary\nA project manager and program ...
# 27  Career Summary\nAn evaluation specialist with ...
# 28  Career Summary\nAn experienced senior .NET dev...
# 29  Shannon Fair Reefer is a registered nurse and ...
# 30  Tina Adler is a senior science writer and edit...
# 31  Dr. Tina Marshall is a Westat Senior Study Dir...
#
#                                                   ETC  \
# 0   M.P.H., Indiana University, 2016\nB.A., Human ...
# 1           B.A., Psychology, Pace University, 1972\n
# 2   M.P.H., Health Policy, Law, and Ethics, Univer...
# 3   Certificate Program in Computer Graphics, Corc...
# 4   M.A., Communication, Johns Hopkins University,...
# 5   M.A., Public Policy and Women’s Studies, Georg...
# 6                      B.S., Education, Texas, 1970\n
# 7   Master’s Degree Equivalent, Sociology, El Salv...
# 8   B.S., Virginia Polytechnic Institute and State...
# 9    Training, and Certifications\nPrinceton Unive...
# 10   Training, and Certifications\n? B.S., Crimina...
# 11   Training, and Certifications\n? Bachelor of F...
# 12   Training, and Certifications\n? B.S.E.E. Comp...
# 13   Training, and Certifications\n? George Washin...
# 14   Training, and Certifications\n? Pennsylvania ...
# 15   Training, and Certifications\n? Graduate Cert...
# 16   Training, and Certifications\n? University of...
# 17   Training, and Certifications\nBS Chemical Eng...
# 18   Training, and Certifications\n? University of...
# 19   Training, and Certifications\n? Doctor in Pub...
# 20   Training, and Certifications\n? PhD, 1995 Ari...
# 21   Training, and Certifications\n? University of...
# 22   Training, and Certifications\n? Harvard Unive...
# 23  B.S., Foreign Service, Georgetown University, ...
# 24   Training, and Certifications\nB.S. Finance, V...
# 25   TRAINING, AND LICENSES\nD.O., Kentucky Colleg...
# 26   Training, and Certifications\n? Columbia Univ...
# 27   Training, and Certifications\n? Georgia State...
# 28   Training, and Certifications\n? Auburn Univer...
# 29  M.P.H., Health Policy and Management, Mailman ...
# 30  M.S., Journalism (with a concentration in Heal...
# 31  Ph.D., Social Welfare, University of Pennsylva...
#
#                                       Work Experience  \
# 0   Westat (2016 to Present), Rockville, MD\nCultu...
# 1   Westat (2009 to Present), Rockville, MD\nHealt...
# 2   Westat (2011 to Present)\nEvaluation of the Pa...
# 3   Westat and Eagle Design & Management (1996 to ...
# 4   Westat and Eagle Design & Management (2005 to ...
# 5   Westat (2000 to 2014, 2016 to Present)\nChildr...
# 6   Westat (2004 to Present)\nCMHS Transformation ...
# 7   Westat and Eagle Design & Management (2004 to ...
# 8   Westat (1997 to Present)\nTechnical Assistance...
# 9   Lead Statistical Programmer\t2017–Present\nMis...
# 10  Project Manager\nDSFederal, Inc., Rockville, M...
# 11  Multimedia Developer\tOctober 2012 – Present I...
# 12  DSFederal, Inc., February 2013 – Present Direc...
# 13  President\t2012 – Present\n\nSenior Vice Presi...
# 14  Travel Coordinator, Project Manager\tNovember ...
# 15  Project Manager, HRSA National Practitioner Da...
# 16  Communications Manager/Technical Writer\tJanua...
# 17  Solutions Architect\tJanuary 2018 – Present\nD...
# 18  Regional Partner Director\t2014 – present\nNE ...
# 19  Project Manager, DSFederal, Inc.\tAug 2018 – P...
# 20  Health Scientist | NCHS/CDC | 1998-Present Pro...
# 21  Communications Specialist\tJuly 2017 – Present...
# 22  Health Scientist,\tFebruary 2018 – Present\nKa...
# 23  Westat (2000 to Present)\nThird-Party Evaluato...
# 24  Business Finance Manager\t03/2014 – Present\nD...
# 25  Karna, LLC\t2018 - present\nVice President, Me...
# 26  Manager, Inmate Services\tSeptember 2017 – Pre...
# 27  Evaluation Specialist (multiple projects)\tDec...
# 28  Data Architect\t2015 - Present\nKarna, LLC, At...
# 29  Westat (2009 to Present)\nEvaluation of the Pa...
# 30  Westat (2010 to Present)\nNHLBI Communications...
# 31  Westat (2003 to Present)\nInterdepartmental Se...
#
#                           Hornors/Awards/Publications  \
# 0                                                None
# 1                                                None
# 2   \nFreed, N., Korsen, N., and Muther, J. (2016,...
# 3   \n? Merit Award (for NEI website), Digital Hea...
# 4                                                None
# 5   \nQuinn, E. (2016). Selecting evidence-based p...
# 6                                                None
# 7   \nJones, C., Nooney, J., Serrani, M.L., and Wi...
# 8                                                None
# 9   \n“Ryan White Services Report (RSR) Client-Lev...
# 10                                               None
# 11  \n? https://mchb.hrsa.gov/training/\n? https:/...
# 12                                               None
# 13                                               None
# 14  \n\n? Lockheed Martin Corporate Communications...
# 15  \n? Director’s Award, Health Resources and Ser...
# 16  \n? DSFederal Employee of the Year, 2017\n? Ph...
# 17                                               None
# 18  \nFox, T., Hager, M., Thompson, A., Van Alst, ...
# 19  \n? Wang HE, Lee M, Hart A, Summers AC, Anders...
# 20  \n? Lauren, RM, Lipphardt A., Ahmad, FB, Keral...
# 21                                               None
# 22  \n? Vaccine, “Attitudes about vaccines to prev...
# 23  \nLorthridge, J., Evans, M., Heaton, L., Steve...
# 24  \n? HRSA Director’s Award for Technical Assist...
# 25                                               None
# 26  \n? 2010 – Health Disparities Champion Award –...
# 27                                               None
# 28                                               None
# 29  \nCarpenter, D., Hassell, S., Mardon, R., Fair...
# 30  \nOutstanding Book Award (for the Alzheimer’s ...
# 31  \nAward for Excellence, Society for Technical ...
#
#                                           ppls_noname
# 0   Emily Abbruzzi is a research assistant with 4 ...
# 1   Patricia Andersen is an editor, writer, and fa...
# 2   Nina Freed is a research analyst with 7 years ...
# 3   Noemi Lucciola is a senior web designer with 1...
# 4   Sandra Paredes is a health communications spec...
# 5   Elizabeth Quinn is a Westat Senior Study Direc...
# 6   Stacey Reddick is a recruitment manager with 1...
# 7   Mariana Serrani is a senior project director w...
# 8   Teresa Strickler is a statistician with 21 yea...
# 9   Career Summary\nMr. Addison is an owner, Direc...
# 10  Career Summary\nAn accomplished professional w...
# 11  Career Summary\nGregory Randal Miller has 30 y...
# 12  Career Summary\n20+ years of software developm...
# 13  Career Summary\nAs the President and Co-Founde...
# 14  Career Summary\nOver 20 years of experience as...
# 15  Career Summary\nMs. Olsen is a certified Proje...
# 16  Claire Pak is a writer and editor with several...
# 17  Career Summary\nSystems architecture, analysis...
# 18  Adam Thompson is a seasoned training specialis...
# 19  Career Summary\nMs. Echo Wang is an experience...
# 20  Career Summary\nAn experienced Data Administra...
# 21  Career Summary\nA senior-level writer/editor w...
# 22  Career Summary\nAn experienced executive lead ...
# 23  Marneena Evans is a research associate with mo...
# 24  Career Summary\nMr. Frank Van Balen is a finan...
# 25  Career Summary\nDr. Durbin is currently the Vi...
# 26  Career Summary\nA project manager and program ...
# 27  Career Summary\nAn evaluation specialist with ...
# 28  Career Summary\nAn experienced senior .NET dev...
# 29  Shannon Fair Reefer is a registered nurse and ...
# 30  Tina Adler is a senior science writer and edit...
# 31  Dr. Tina Marshall is a Westat Senior Study Dir...

# %%
#Storing the dataframe

file_name = data_folder / "intermediate/All_Phase1_A.pkl"
df2.to_pickle(file_name)
